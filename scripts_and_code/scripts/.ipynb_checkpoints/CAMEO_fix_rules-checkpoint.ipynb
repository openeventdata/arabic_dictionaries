# %%
import requests
import pyarabic.araby as araby # for processing arabic 
import re

# %%
#reading the CAMEO arabic rules file
rules =[]
with open('CAMEO.ar.0.2.txt', 'rb') as input_file :
    for line in input_file : 
        if line != '':
            rules.append(line.decode('utf-8') )
        
rules = [i.replace('\n','') for i in rules]
# rules = [i for i in rules if i !='']
rules[:30]
# Out:
# ['# LAST UPDATE: 11 July 2018',
#  '',
#  '####### SYNONYM SETS ####### ',
#  '&CURRENCY',
#  '',
#  '+درهم_مغربي_',
#  '+فرنك_كونغولي_',
#  '+ناكفا_',
#  '+فرنك_سويسري_',
#  '+نيرة_نيجيرية_',
#  '+تالا_',
#  '+روبية_نيبالية_',
#  '+يورو_',
#  '+بيسو_فلبيني_',
#  '+كوردبا_نيكاراغوا_',
#  '+كرون_إستوني_',
#  '+ساماني_طاجيكي_',
#  '+دينار_تونسي_',
#  '+دولار_غياني_',
#  '+سيدي_',
#  '+مارك_',
#  '+نغولترم_',
#  '+دولار_جامايكي_',
#  '+بات_',
#  '+هريفنا_',
#  '+دولار_البليز_',
#  '+بيزو_أرجنتيني_',
#  '+أوقية_',
#  '+دينار_',
#  '+درام_أرميني_']

# %%
x = ''
for i in rules :
    if i.startswith('- *') : 
        x = i
        break
y = x.split('#')
y[0]
# Out:
# '- * (ل حد)   [154] '

# %% [markdown]
# ## UDpipe approach

# %%
# http://lindat.mff.cuni.cz/services/udpipe/api/process?tokenizer&tagger&model=arabic-ud-2.0-170801&data=الجرائم
acceptable_formats = ['-*[]',"-*()[]", "-*{}[]"  , "-*({})[]", '-*()[]' , '-*()()[]', '-*({})()[]', '-*{()}[]' , '-*(())[]', '-*({()})[]' , '-*(){}[]']
special_formats = ['-*()', '-*()()[]' , '', '-*(}})[]' , '-*}}[]', '-*{}[]' , '-*([]' , '-*({({()[]'  , '-*(}()(}[]' , '-*))[]', '-*((}(})[]']
wrong_skip = ['* نزع سلاح) جهود)' , ' * عن تقرير مصير) بيان)', '* عن تقرير مصير) بيان)' , '* ((مساعدات انسانية} (من أجل})']
encod_chars = ['-' , '*' , '(' , ')' , '[' , ']' , '{','}']
#store things for later
special = []
to_be_replaced = []
error =[]

def check_and_reconstruct_rule(rule): 
    rule = ' '.join(rule.split()) # to remove all white spaces and duplicate ones 
    if rule == '' :
        return 'ERROR'
    
    rule_encod = ''.join([i for i in rule if i in encod_chars])
#     print('RULE : {} || ENCODE : {}'.format(rule , rule_encod))
    
    if rule_encod in acceptable_formats: #verb is already correct(rare cases)- apply regex stright
        return rule
    elif rule_encod in special_formats:
#         print("YES")
        return 'SPECIAL'
    else : 
        if rule_encod == '-*({{)[]': # -*({{)[]
            t = rule.find('{')
            rule = rule[:t] + rule[t+1: -1] + '})'
            rule_encod =''.join([i for i in rule if i in encod_chars])
        elif rule_encod  =='*((':
            t =  rule.find('(')
            rule = rule[:t] + rule[t+1:] + ')'
            rule_encod =''.join([i for i in rule if i in encod_chars])
        elif rule_encod  =='*{{':
            t =  rule.find('{')
            rule = rule[:t] + rule[t+1:] + '}'
            rule_encod =''.join([i for i in rule if i in encod_chars])
        elif rule_encod =='*{((}' : 
            t = rule.find('(')
            rule = rule[:t] + rule[t+1: -1] + ')}'
            rule_encod =''.join([i for i in rule if i in encod_chars])
        elif rule_encod == '*{){)': 
            t = rule.find('{')
            rule = rule[:t] + '(' + rule[t+1: -1] + '}'
            rule_encod =''.join([i for i in rule if i in encod_chars])
            
        
        if rule_encod not in acceptable_formats :
            print('ERR | {} | {}'.format(rule, rule_encod))
            return 'ERROR'
        else :
#             print('FIX | {} | {}'.format(rule, rule_encod))
            return rule
    
    return rule

def rule(i):
    if i.strip()[0] != '-' : # Wrong delete 
        print('NEED MANUAL FIX :{}'.format(i)) # delete those need to mananually fix
        special.append(i)
        return i
    elif re.search('[a-zA-Z]', i) : 
        to_be_replaced.append(i)
        return i
    
    elif i in wrong_skip : 
        print('SKP | {}'.format(i))
        return i
    else : 
        if '$' in i or '+' in i or '^' in i or '/' in i or '|' in i :
            i = ''.join([c for c in i if c not in set(['$', '+', '^', '/' , '|'])])
            print("EHH :{}".format(i))
        rule_fixed = check_and_reconstruct_rule(i.strip())
        if rule_fixed == i :
            return i
        elif rule_fixed == 'SPECIAL':
            print('NEED MANUAL FIX :{}'.format(i))
            special.append(i)
            return 'SPECIAL'
        elif rule_fixed == 'ERROR' :
            print('RET ERR :{}'.format(i))
            error.append(i)
            return 'ERROR'
        else :  # fixed by now
#             print('is all good')
            return rule_fixed

# %%
for i in range(len(rules)) : 
    if rules[i].startswith('- *'): 
        sp_re = rules[i].split('#')
        o_r = sp_re[0]
        utl_part = sp_re[1]
        r = rule(o_r)
        if r =='ERROR':
            print('-----------------')
            print('old_ :{}'.format(o_r))
            print('new_ :{}'.format(r))
            print('-----------------')
            break
        elif r == 'SPECIAL':
            print('-------SPECAIL----------')
            print('old_ :{}'.format(o_r))
            print('new_ :{}'.format(r))
            print('-----------------')
        else :
            rules[i] = r + ' #{}'.format(utl_part)
            print(rules[i])
# Out:
# - * (ل حد) [154] # عمل_بسرعة,سرع,هرل,اِنْطلق_بِسُرْعة,عجل,هرع
# - * (إلى حد) [154] # عمل_بسرعة,سرع,هرل,اِنْطلق_بِسُرْعة,عجل,هرع
# - * معونة [070] # عمل_بسرعة,سرع,هرل,اِنْطلق_بِسُرْعة,عجل,هرع
# - * مساعدة [070] # عمل_بسرعة,سرع,هرل,اِنْطلق_بِسُرْعة,عجل,هرع
# - * (ل {الاحزاب الممنوعة}) [1722] # اضاف
# - * (ل {الاحزاب الممنوعة}) [1722] # اضاف
# - * &SECURITY (من {&WEAPON ATTACK})   [151]  # نبه,نذر,حذر
# - * صفقة [031] # راجع
# - * دستور [0344] # راجع
# - *(في محكمة) [173] # بدا,رأى_النور,تضح,ظهر
# - *في مصلحة [050] # بدا,رأى_النور,تضح,ظهر
# - *في صالح [050] # بدا,رأى_النور,تضح,ظهر
# - * &WEAPON خلف   [190]  # بدا,رأى_النور,تضح,ظهر
# - * خلف &WEAPON   [190]  # بدا,رأى_النور,تضح,ظهر
# - *(في محكمة) [173] # بدا,رأى_النور,تضح,ظهر
# - * خلف &WEAPON   [190]  # بدا,رأى_النور,تضح,ظهر
# - * (في ضغط) (لرفد) [1041] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (من أجل إخراج) (ل ضغط) [1041] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى {عقوبة جديد}) [1312] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى بيان) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى مصرع) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن صلة) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى اتهام) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن {حلقة وصل}) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن رابطة) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى شكاوي) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى تهمة) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن وصلة) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى بلاغ) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى تهمة) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى تقرير) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى وفاة) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى ادعاء) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى تذمر) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى موت) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن ارتباط) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى زعم) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن علاقة) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى اتهام) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى نحب) [090] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * مقدم [013] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (إلى مستقبل)(بتفاول) [013] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * اماما [013] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن مساعدة) [020] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * (عن طريق) [032] # بدا,حقق+في,طلع,نظر_بتركيز,نظر+على,نظر,سعى+الى,تفقد,تطلع+الى,رقب,حدق,رأى,اجتاس
# - * &CEASEFIRE   [0356]  # رتب,نظم
# - * شرط (قبل نهاية) [139] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * {موعد نهائي} [139] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (باحتجاج) [145] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نفس هوو (ب نار) [145] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (احتجاج) [145] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (في الراية) [140] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * علم [140] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (في علم) [140] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * حر [0841] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * يحرر [0841] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * حريق [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * حريق [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * مشتعل [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * شرط [100] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * ارشادات [045] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - *تعليم [045] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * (جانب الانشقاق) [030] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * خلاف (جانب) [030] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * (ل &TREATY)   [035]  # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * دبلوماسي [161] # بنى,نشأ,اقم,اسس
# - * (في {حالة تنبيه}) [152] # وضع,وقع,وضعه_فى_موضع_معين
# - * (في {حالة تأهب}) [152] # وضع,وقع,وضعه_فى_موضع_معين
# - * (تحت مراقبة) [173] # وضع,وقع,وضعه_فى_موضع_معين
# - * (في &DETENTION)   [173]  # وضع,وقع,وضعه_فى_موضع_معين
# - * (في {حالة تأهب}) (على حد) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * احتجاج [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * اعتراض [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للانتخاب) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للتصويت) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * حرارة [111] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * عصيان [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * {عمل شغب} [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (إلى موت) [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * محاكمة [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * احتجاج (ل دعم) [051] # نظم
# - * احتجاج ل [051] # نظم
# - * مظاهرة تضامنا أمامنا [051] # نظم
# - * مظاهرة (في دعم) [051] # نظم
# - * هجوم [190] # نظم
# - * هجمة [190] # نظم
# - * ضربة [190] # نظم
# - * مظاهرة [141] # نظم
# - * مسيرة [141] # نظم
# - * صفح [0351] # طلب,رجا,استرفد,سأل
# - * عفو [0351] # طلب,رجا,استرفد,سأل
# - * (ل{مساعدة إنساني}) [0233] # طلب,رجا,استرفد,سأل
# - * إخلاء [0233] # طلب,رجا,استرفد,سأل
# - * {&AIRCRAFT حربي}   [0232]  # طلب,رجا,استرفد,سأل
# - * (ل{مساعدة نقدية}) [0231] # طلب,رجا,استرفد,سأل
# - * (ل{مساعدة مالية}) [0231] # طلب,رجا,استرفد,سأل
# - * اعتذار [110] # طلب,رجا,استرفد,سأل
# - * (ل مساعدة) (في &SECURITY)   [0234]  # طلب,رجا,استرفد,سأل
# - * (لولوج) [025] # طلب,رجا,استرفد,سأل
# - * (ل دخول) [025] # طلب,رجا,استرفد,سأل
# - * (لسماح) [025] # طلب,رجا,استرفد,سأل
# - * (ل إعادة محاكمة) [0213] # طلب,رجا,استرفد,سأل
# - * ملفة [0214] # طلب,رجا,استرفد,سأل
# - * (ل &SOLUTION) (عن &INVESTIGATION)   [0214]  # طلب,رجا,استرفد,سأل
# - * (ل &INVESTIGATION)   [0214]  # طلب,رجا,استرفد,سأل
# - * تاكيدات [022] # طلب,رجا,استرفد,سأل
# - * عفو [055] # طلب,رجا,استرفد,سأل
# - *عفو [055] # طلب,رجا,استرفد,سأل
# - * مساعدة [020] # طلب,رجا,استرفد,سأل
# - * توضيح [020] # طلب,رجا,استرفد,سأل
# - * دعم [023] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * صفح [023] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * عفو [023] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * مساعدة [023] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * إنساني [0233] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * تسليم [0213] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * تفويض [020] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * اعتقال [020] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * توكيل [020] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * ترخيص [020] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * إيقاف [020] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * ضد [113] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * {مشاركة معلومة} [0214] # طلب,رجا,قدم_طلبا,قدم+طلبا+ل,سأل
# - * زعم [090] # سءل,تساءل+عن
# - * اتهام [090] # سءل,تساءل+عن
# - * ادعاء [090] # سءل,تساءل+عن
# - * تأكيد [110] # سءل,تساءل+عن
# - * (ل{مساعدة إنساني}) [0233] # طلب,رجا,استرفد,سأل
# - * {&AIRCRAFT حربي}   [0232]  # طلب,رجا,استرفد,سأل
# - * (ل مساعدة) (في &SECURITY)   [0234]  # طلب,رجا,استرفد,سأل
# - * (ل دخول) [025] # طلب,رجا,استرفد,سأل
# - * (ل إعادة محاكمة) [0213] # طلب,رجا,استرفد,سأل
# - * ملفة [0214] # طلب,رجا,استرفد,سأل
# - * تاكيدات [022] # طلب,رجا,استرفد,سأل
# - * عفو [055] # طلب,رجا,استرفد,سأل
# - * اغتيال [185] # سعى_لعمل_شئ,حول,قام_بمحاولة,جرب_حظه,حاول_الإعتداء,حاول,جرب,سعى
# - * محاولة (على حياة) [185] # جنب
# - * (من عنف) [087] # امتنع
# - * أزمة [037] # تجنب
# - * (أزمة) [037] # تجنب
# - * (من عمل) [1211] # منع,امتنع,عزف__عن,كف_عن,كف,حجم,ترك,اِمْتنع_عن
# - * (من مهنة) [1211] # منع,امتنع,عزف__عن,كف_عن,كف,حجم,ترك,اِمْتنع_عن
# - * (من محل) [1211] # منع,امتنع,عزف__عن,كف_عن,كف,حجم,ترك,اِمْتنع_عن
# - * (من عمل) [1211] # منع,امتنع,عزف__عن,كف_عن,كف,حجم,ترك,اِمْتنع_عن
# - * خطير [012] # ظن,صدق,اعتقد,امن,عقد,وثق
# - * خطر [012] # ظن,صدق,اعتقد,امن,عقد,وثق
# - * صديق [050] # ظن,صدق,اعتقد,امن,عقد,وثق
# - *أزر [050] # ظن,صدق,اعتقد,امن,عقد,وثق
# - *رفيق [050] # ظن,صدق,اعتقد,امن,عقد,وثق
# - *أزر [050] # ظن,صدق,اعتقد,امن,عقد,وثق
# - * (من أجل) هجوم [154] # استعد
# - * (ل هجوم) [154] # استعد
# - * {خطاب رسمي} [010] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * خطبة [010] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * خطاب [010] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * &MILITARY   [072]  # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * معونة [073] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * مساعدة [073] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * هبة [070] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * هدية [070] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * ضربة [120] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * هجمة [120] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * {حجة مضاد} [110] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * أمصأدقة [051] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * موافقة [051] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * منا شدة [020] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * طلب [020] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - * استئناف [020] # لقى,وصل,رسل,ألقى_خطابا,سلم,القى,قدم,عطى
# - *منزل [1712] # أوقد,أجج,شعل,حرق,احرق
# - *بيت [1712] # أوقد,أجج,شعل,حرق,احرق
# - * راية [141] # أوقد,أجج,شعل,حرق,احرق
# - * علم [141] # أوقد,أجج,شعل,حرق,احرق
# - * تمثال [141] # أوقد,أجج,شعل,حرق,احرق
# - * &TREATY   [131]  # لغى,الغى
# - * صفقة [160] # لغى,الغى
# - * اتفاق [160] # لغى,الغى
# - * معسكر [0874] # ترك
# - * مكتب [160] # نسد,حجز,قفل,سد,نهى,اغلق,غلق
# - * حد [160] # نسد,حجز,قفل,سد,نهى,اغلق,غلق
# - * مقر [160] # نسد,حجز,قفل,سد,نهى,اغلق,غلق
# - * دبلوماسي [161] # نسد,حجز,قفل,سد,نهى,اغلق,غلق
# - * التلفاز [1721] # نسد,حجز,قفل,سد,نهى,اغلق,غلق
# - * {إطلاق نار} [0871] # انتهى,انهى
# - * حصار [087] # انتهى,انهى
# - * صدام [0871] # قطع,وقف
# - * هجمة [0871] # قطع,وقف
# - * طيران [160] # قطع,وقف
# - * مساعدة [162] # قطع,وقف
# - * معونة [162] # قطع,وقف
# - * هجوم [0871] # قطع,منع,وقف,نهى,انهى
# - * مساعدة [1621] # قطع,منع,وقف,نهى,انهى
# - * منح [1621] # قطع,منع,وقف,نهى,انهى
# - * ترحيل [080] # قطع,منع,وقف,نهى,انهى
# - * مجزرة [087] # قطع,منع,وقف,نهى,انهى
# - * {سفك دم} [087] # قطع,منع,وقف,نهى,انهى
# - * حصار [085] # قطع,منع,وقف,نهى,انهى
# - * (إلى شارع) [141] # تلقى,اخذ,سيطر+على
# - *( إلى &DETENTION)   [173]  # تلقى,اخذ,سيطر+على
# - * (بمرارة) [110] # تلقى,اخذ,سيطر+على
# - * &WEAPON   [0356]  # تلقى,اخذ,سيطر+على
# - * سيطرة [192] # تلقى,اخذ,سيطر+على
# - * مقاطعة [192] # تلقى,اخذ,سيطر+على
# - * (على &TOWN)   [192]  # تلقى,اخذ,سيطر+على
# - * مطوق [192] # تلقى,اخذ,سيطر+على
# - * تحكم [192] # تلقى,اخذ,سيطر+على
# - * محاصرة [192] # تلقى,اخذ,سيطر+على
# - *{مجال جوي} [172] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - *حد [172] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - *مركز [172] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - *{طريق سريع} [172] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * منفذ [191] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * مطار [191] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * مدخل [191] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * &INFORMATION   [1721]  # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * مع تنبيه [012] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * مع انذار [012] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * مع تحذير [012] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * مخيم [160] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * معسكر [160] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * مخيمات [160] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * قاعدة [160] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * سفارة [161] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - * قنصلية [161] # ختم,طوى,نسد,زنأ,قفل,سد,نهى,فض,اغلق,غلق
# - *  {&MILITARY RESERVE}   [153]  # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل نشر) [0233] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل &ASYLUM)   [0233]  # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * مجرم [1121] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * اجرامي [1121] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل &PKO)   [0234]  # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * ( {&SECURITY ل {تدبير)   [0234]  # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل حماية) [0234] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * انتخاب [0831] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لاقالة) [110] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل فصل) [110] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل {عمل دولي}) [113] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل عمل ضد) [113] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لتعليق) [113] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل علاقة) [030] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل أجل &FIGHT)   [138]  # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لمحادثات) [036] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لنهاية) [053] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * ل إنهاء [053] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (عملية) (ل إنهاء) [1056] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (&INVESTIGATION إلى)   [090]  # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (&INVESTIGATION (من أجل))   [090]  # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل قوة) [0232] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لانتخابات) [0241] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل إقالة) [0241] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لاستقالة) [0241] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل عقوبة) [1312] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (للاستقلال) [0244] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لاستقلال) [0244] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل وقف) [087] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل إيقاف) [025] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل سحب) [025] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل سحب) [025] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لتنازل) [025] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل تجديد) [021] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل إنهاء) [020] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (على) [020] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (بناء على) [020] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل تحالف) [020] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل زيادة) [023] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل علاقة) [022] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ب صحافة) [041] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (لحملة قمع) [111] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * شيطان [111] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * دكتاتور [111] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * (ل أجل {هجوم انتحاري}) [1383] # نادى_على,كلم,لقب,تصل,دعا_ب,طلب,خاطب_تلفونيا,ناشد,نادى+ب,ندى,اتصل,دعا+الى,دعى,سأل,دعا,نادى_بسخرية,خاطب_بالتليفون,نادى,هتف
# - * موت [111] # ترنم,هتف
# - * (في مظاهرة) [141] # ترنم,هتف
# - * ضد حكومة [141] # ترنم,هتف
# - * (في عاصمة) [141] # ترنم,هتف
# - * ضد حكومة [141] # ترنم,هتف
# - *تحت [173] # قمع,فرض
# - * {حظر تجول} [1723] # قمع,فرض
# - * &TREATY   [050]  # حصل+على
# - * مستند [090] # لم,ضبر,حشد,جمع,دخر,كنز
# - * وثيقة [090] # لم,ضبر,حشد,جمع,دخر,كنز
# - * ورق [090] # لم,ضبر,حشد,جمع,دخر,كنز
# - * مستند [090] # لم,ضبر,حشد,جمع,دخر,كنز
# - * وثيقة [090] # لم,ضبر,حشد,جمع,دخر,كنز
# - * ورق [090] # لم,ضبر,حشد,جمع,دخر,كنز
# - * زعم [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * ادعاء [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * صرف [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * إقالة [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * {إطلاق نار} [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * طرد [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * مزعم [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * نار [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * اعتقال [173] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * { مقاطعة تجمع} [125] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * {مقاطعة اجتماع} [125] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * مقاطعة [163] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * {إطلاق نار} [010] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * { مقاطعة تجمع} [125] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - * {مقاطعة اجتماع} [125] # قوى,جزم,اكد,وكد,صدق,ثبت,أكد_مجددا,علم_مؤكدا,قدّم_الدّلِيل,عزز,قدم_برهان
# - *تعهد [050] # أكد_صحة_شىء_ما,ثبت,جزم,اكد
# - *التزام [050] # أكد_صحة_شىء_ما,ثبت,جزم,اكد
# - * انتخاب [0341] # اثبت,اكد
# - * دعم [051] # اثبت,اكد
# - *قلق [012] # اثبت,اكد
# - * اهتمام [012] # اثبت,اكد
# - * التزام (ضد تهديد) [130] # اثبت,اكد
# - * تعهد (ضد تهديد) [130] # اثبت,اكد
# - * &OPPOSITION   [110]  # اثبت,اكد
# - * ادعاء [100] # اثبت,اكد
# - * إصرار [030] # اثبت,اكد
# - * شرط (قبل نهاية) [139] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * {موعد نهائي} [139] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (باحتجاج) [145] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نفس هوو (ب نار) [145] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (احتجاج) [145] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (في الراية) [140] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * علم [140] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار (في علم) [140] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * حر [0841] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * يحرر [0841] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * حريق [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * نار [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * حريق [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * مشتعل [180] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * شرط [100] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * ارشادات [045] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - *تعليم [045] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * (جانب الانشقاق) [030] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * خلاف (جانب) [030] # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * (ل &TREATY)   [035]  # وضع,أضرم+النار+في,اسس,حدد,احرق
# - * حاجز [160] # بنى,اسس
# - * سياج (على حد) [160] # بنى,اسس
# - * (إلى شارع) [141] # تلقى,اخذ,سيطر+على
# - *( إلى &DETENTION)   [173]  # تلقى,اخذ,سيطر+على
# - * (بمرارة) [110] # تلقى,اخذ,سيطر+على
# - * &WEAPON   [0356]  # تلقى,اخذ,سيطر+على
# - * سيطرة [192] # تلقى,اخذ,سيطر+على
# - * مقاطعة [192] # تلقى,اخذ,سيطر+على
# - * (على &TOWN)   [192]  # تلقى,اخذ,سيطر+على
# - * مطوق [192] # تلقى,اخذ,سيطر+على
# - * تحكم [192] # تلقى,اخذ,سيطر+على
# - * محاصرة [192] # تلقى,اخذ,سيطر+على
# - * سياج (على حد) [150] # قام+ببناء,اقم,نشأ,شيد,بنى,عمل_في_صناعة_البناء,هيأ
# - * حاجز [150] # قام+ببناء,اقم,نشأ,شيد,بنى,عمل_في_صناعة_البناء,هيأ
# - * تحصينات [154] # قام+ببناء,اقم,نشأ,شيد,بنى,عمل_في_صناعة_البناء,هيأ
# - * تحصين [154] # قام+ببناء,اقم,نشأ,شيد,بنى,عمل_في_صناعة_البناء,هيأ
# - * جهد [060] # ادام,استمر+في,استدام
# - * جهد [060] # ادام,استمر+في,استدام
# - * المجهود [060] # ادام,استمر+في,استدام
# - * &MEDIATION   [045]  # ادام,استمر+في,استدام
# - *حملة [170] # ادام,استمر+في,استدام
# - *قمع [170] # ادام,استمر+في,استدام
# - * {عملية قصف} [190] # ادام,استمر+في,استدام
# - * هجومات [190] # ادام,استمر+في,استدام
# - * قذف [190] # ادام,استمر+في,استدام
# - * ضربة [190] # ادام,استمر+في,استدام
# - * هجمة [190] # ادام,استمر+في,استدام
# - * ضرب [190] # ادام,استمر+في,استدام
# - * قصفة [190] # ادام,استمر+في,استدام
# - * قصف [190] # ادام,استمر+في,استدام
# - * حظر [163] # ادام,استمر+في,استدام
# - * (من خلال) [190] # تقدم
# - * نحو [190] # تقدم
# - * عبر [190] # تقدم
# - * جهد [060] # ادام,استمر+في,استدام
# - * ضربة [190] # ادام,استمر+في,استدام
# - * هجمة [190] # ادام,استمر+في,استدام
# - * مقاطعة [1054] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * ميعاد [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * عمل [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * (من أجل) [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * (كغير مقبول) [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * (كمستفز) [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * تصرف [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * فعل [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * إدانة [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * &CRIME   [111]  # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * (ل) [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * (كاستفزازي) [111] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * قنبلة [193] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * {قنبلة يدوي} [193] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * رمانة [193] # ندد+ب,غلق_بقوة,سفق,حدث_ضجة_عالية,خبط,هجن,غلق_بعنف,أغْلق_بِعُنْف,ضرب_بعنف,صفق,سحق
# - * تعقبا [190] # جاز,قطع,عبر
# - * ملاحقة [190] # جاز,قطع,عبر
# - * سعي [190] # جاز,قطع,عبر
# - * مطاردة [190] # جاز,قطع,عبر
# - * تعقبا [190] # جاز,قطع,عبر
# - * ملاحقة [190] # جاز,قطع,عبر
# - * سعي [190] # جاز,قطع,عبر
# - * مطاردة [190] # جاز,قطع,عبر
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * &PROPOSAL   [120]  # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * قضية [081] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * (كاختلاق) [111] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * (كتلفيق) [111] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * (كظلم) [111] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * تنصيب [110] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * محافظ [110] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * توظيف [110] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * تعين [110] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * ميعاد [110] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * ادعاء [016] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * اتهام [016] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * تهمة [016] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * دعوى [016] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * زعم [016] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * مطالبة [016] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * تهمة [016] # صرف_النّظر_عن,اقل,رفض,صرف__مِن_الخِدْمة,فصل,اقال,أعْفى_مِن_الخِدْمة,أنْهى_خِدْمة,جهل,طرد,همل,صرف_الْنّظر_عن,نبذ
# - * (إلى) [061] # صدر
# - * (في {حالة تأهب}) (على حد) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (في {حالة تأهب}) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * احتجاج [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * اعتراض [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للانتخاب) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للتصويت) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * حرارة [111] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * عصيان [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * {عمل شغب} [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (إلى موت) [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * محاكمة [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * (&PKO كتئبة (من   [074]  # ارسل
# - * &SOLUTION   [030]  # وصل,وجد,عرض,كشف,القى
# - * م توفي [190] # وصل,وجد,عرض,كشف,القى
# - * موتى [190] # وصل,وجد,عرض,كشف,القى
# - * ميت [190] # وصل,وجد,عرض,كشف,القى
# - * (من ملامة) [120] # تباعد+عن,جنب,بعد
# - * (من لوم) [120] # تباعد+عن,جنب,بعد
# - * (من &PROPOSAL)   [120]  # تباعد+عن,جنب,بعد
# - * (من) [110] # تباعد+عن,جنب,بعد
# - * (عن تعليقات) [016] # تباعد+عن,جنب,بعد
# - * (عن ملاحظة) [016] # تباعد+عن,جنب,بعد
# - * (عن ملاحظة) [016] # تباعد+عن,جنب,بعد
# - * قانون [031] # صاغ,قام+بصياغة
# - * دستور [014] # صاغ,قام+بصياغة
# - * {قانون أساسي} [014] # صاغ,قام+بصياغة
# - * ارشادات [014] # صاغ,قام+بصياغة
# - * قانون [014] # صاغ,قام+بصياغة
# - * {مشروع قانون} [014] # صاغ,قام+بصياغة
# - * قانون [014] # صاغ,قام+بصياغة
# - *(في &TOWN) ال &DISPUTE   [037]  # صاغ,قام+بصياغة
# - * &PROPOSAL (لغارة) (ضد)   [035]  # صاغ,قام+بصياغة
# - * {قانون أساسي} [014] # صاغ,قام+بصياغة
# - * قانون [014] # صاغ,قام+بصياغة
# - * (بعيد عن) [201] # طرد,دفع
# - * خارج [201] # طرد,دفع
# - * (خارج عن) [201] # طرد,دفع
# - * (بعيد عن) [201] # طرد,دفع
# - * (خارج عن) [201] # طرد,دفع
# - * {مشروع قانوني} [0834] # تبع,قلد,مثل,اعتمد
# - * قانون [0834] # تبع,قلد,مثل,اعتمد
# - * &SOLUTION   [057]  # تبع,قلد,مثل,اعتمد
# - * بيان (عن سيادة) [1044] # تبع,قلد,مثل,اعتمد
# - * تسليم [070] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * تسليم [070] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * تسليم [070] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * توصيل [070] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * انتخاب [083] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * &MEDIATION   [038]  # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * اتهام [015] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * تهمة [015] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * &PROPOSAL   [032]  # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * &REFUGEE   [0333]  # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * &TREATY   [030]  # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * تشكيل [030] # أفاد_الموافقة,سمح_بِـ,رضى,رضي,صدق,اقر+ب,وفق,اقر,يوافق+على,قبل,رضِي_بـِ,سلم,وافق+على,سلم+ل,وَافَقَ_عَلَى,سَمَحَ_بِـ,وصل+الى,اتبفق+ب
# - * (ك &NEGOTIATOR)   [045]  # برز
# - * (ك &NEGOTIATOR)   [045]  # برز
# - * &MILITARY   [150]  # ما+زال,بقى,مكث,ظل,بقي
# - * (في جمود) [120] # ما+زال,بقى,مكث,ظل,بقي
# - * متحد [120] # ما+زال,بقى,مكث,ظل,بقي
# - * جمود [120] # ما+زال,بقى,مكث,ظل,بقي
# - * عاص [120] # ما+زال,بقى,مكث,ظل,بقي
# - * مسدود [120] # ما+زال,بقى,مكث,ظل,بقي
# - * قلمق [012] # ما+زال,بقى,مكث,ظل,بقي
# - * مهتم [012] # ما+زال,بقى,مكث,ظل,بقي
# - * قلق [012] # ما+زال,بقى,مكث,ظل,بقي
# - * واثق [013] # ما+زال,بقى,مكث,ظل,بقي
# - * مقتنع [013] # ما+زال,بقى,مكث,ظل,بقي
# - * بعيد (للسلم) [124] # ما+زال,بقى,مكث,ظل,بقي
# - * بعيد (ل سلام) [124] # ما+زال,بقى,مكث,ظل,بقي
# - * قريب [050] # ما+زال,بقى,مكث,ظل,بقي
# - *قريب [050] # ما+زال,بقى,مكث,ظل,بقي
# - * متعهد [051] # ما+زال,بقى,مكث,ظل,بقي
# - * ملتزم [051] # ما+زال,بقى,مكث,ظل,بقي
# - * &NEGOTIATION   [036]  # دخل+في,دخل
# - * (لاجل لاجل {علاج طبي}) [074] # خلى
# - * (ل أجل {علاج طبي}) [074] # خلى
# - * مخيم [160] # خلى
# - * عوائل [073] # خلى
# - * (لاجل لاجل {علاج طبي}) [074] # خلى
# - * (ل أجل {علاج طبي}) [074] # خلى
# - * (إلى شارع) [141] # تلقى,اخذ,سيطر+على
# - *( إلى &DETENTION)   [173]  # تلقى,اخذ,سيطر+على
# - * (بمرارة) [110] # تلقى,اخذ,سيطر+على
# - * &WEAPON   [0356]  # تلقى,اخذ,سيطر+على
# - * سيطرة [192] # تلقى,اخذ,سيطر+على
# - * مقاطعة [192] # تلقى,اخذ,سيطر+على
# - * (على &TOWN)   [192]  # تلقى,اخذ,سيطر+على
# - * مطوق [192] # تلقى,اخذ,سيطر+على
# - * تحكم [192] # تلقى,اخذ,سيطر+على
# - * محاصرة [192] # تلقى,اخذ,سيطر+على
# - * محاولة [080] # تخلّى_عن,تخلى+عن
# - * مقر [0874] # تخلّى_عن,تخلى+عن
# - * ثقة ضد [110] # اظهر
# - * &PROGRAM   [060]  # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - * دليل [1124] # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - * &PROPOSAL   [020]  # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - * مع توقيع [017] # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - * (مع مطلب) [100] # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - * مجلس وزير [050] # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - * ورق اعتماد (كسفير) [050] # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - *ورق اعتماد (كسفير) [050] # حضر,شرح,مثل,عرض+على,قدم_نفسه,عرض,قدم
# - * {يد مساعدة} [070] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * &SOLUTION   [160]  # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * تهنئة [051] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * تهاني [051] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * عقد [030] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * تعزية [018] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * مواساة [018] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * عفو [056] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * عفو عام [056] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * سيطرة [192] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * تحكم [192] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * تنظيم [192] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * &DETENTION   [173]  # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - *منع [172] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * حظر [172] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * منع (على استيراد) [163] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * {يد مساعدة} [070] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * تعزية [018] # نشر,اطل,ضخم,متد,وسع,مدد,مد,اصدر,بسط,زود,وجه,مط,عرض,مطط,قدم,زاد
# - * محاولة [121] # خفق,فشل,فشل+في
# - * جمود سياسي [030] # كسر,انفصل
# - *تازم [030] # كسر,انفصل
# - * (مع) [130] # كسر,انفصل
# - * (عن) [130] # كسر,انفصل
# - * ب عيد [130] # كسر,انفصل
# - * بعيد [130] # كسر,انفصل
# - * صفقة [057] # ضرب,وقع,توصل+الى,أضرب+عن
# - * اتفاق [057] # ضرب,وقع,توصل+الى,أضرب+عن
# - * قضية ضد [115] # قدم
# - * قضية ضد [115] # قدم
# - * شكوى [114] # قدم
# - * تهمة (ضد) [173] # قدم
# - * استئناف [1043] # قدم
# - * قضية ضد [115] # قدم
# - * (إلى) [036] # طير,طار+الى
# - * (لاجل لاجل علاج) [073] # طير,طار+الى
# - * (ل أجل العلاج) [073] # طير,طار+الى
# - * &CURRENCY   [071]  # طير,طار+الى
# - * (إلى) [036] # طير,طار+الى
# - * (لاجل لاجل علاج) [073] # طير,طار+الى
# - * (ل أجل العلاج) [073] # طير,طار+الى
# - * {إمدادات إنساني} [073] # قام+بجسر+جوي+ل
# - * (ب واسطة) [073] # قام+بجسر+جوي+ل
# - * (ب) [073] # قام+بجسر+جوي+ل
# - * {إمدادات إنساني} [073] # قام+بجسر+جوي+ل
# - * محاولة [1246] # احبط
# - * دعوة [1246] # احبط
# - * عرض [1246] # احبط
# - * إحداث (ب قلق) [012] # تبع,عقب
# - * إحداث (ب قلق) [012] # تبع,عقب
# - * معيار [030] # استوفى,وفى_ب
# - * معيار [030] # استوفى,وفى_ب
# - * (في الحاسوب) [176] # اخترق
# - *كومبيوتر [176] # اخترق
# - *الحاسوب [176] # اخترق
# - * شبكة [176] # اخترق
# - * (حتي موت) [1823] # اخترق
# - * (حتي موت) [1823] # اخترق
# - * معارضة [128] # رمى,القى
# - * جموح [128] # رمى,القى
# - * اتهام [111] # رمى,القى
# - * ريب [012] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * شك [012] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * ارتياب [012] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * اقتراع [014] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * تصويت [014] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * قرعة [014] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * ريب [110] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * شك (على ادعاء) [110] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * شك [110] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * شك (على ادعاء) [110] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * ريب (على ادعاء) [110] # لقى,ألقى_الضوء_على,اثار,القى+على,ادلى
# - * منا شدة [122] # تجاهل
# - * استئناف [122] # تجاهل
# - * قرار [160] # تجاهل
# - * انتقاد [016] # تحدى
# - * نقد [016] # تحدى
# - * منا شدة [122] # تجاهل
# - * رغبة [013] # اشر,اشار+الى
# - * طلب [013] # اشر,اشار+الى
# - * (عن عملية) [064] # اطلع
# - * &WEAPON   [1711]  # اعترض
# - * &REFUGEE   [170]  # اعترض
# - * أساس (ل هجوم) [154] # وضع,وضعه_فى_موضع_معين
# - * أساس (لبداية لبداية هجوم) [154] # وضع,وضعه_فى_موضع_معين
# - * (في {حالة تأهب}) (على حد) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (في {حالة تأهب}) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * احتجاج [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * اعتراض [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للانتخاب) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للتصويت) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * حرارة [111] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * عصيان [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * {عمل شغب} [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (إلى موت) [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * محاكمة [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * أساس (ل هجوم) [154] # وضع,وضعه_فى_موضع_معين
# - * أساس (لبداية لبداية هجوم) [154] # وضع,وضعه_فى_موضع_معين
# - * حظر [081] # رفع
# - * حصار [0872] # رفع
# - * حظر تجول [0813] # رفع
# - * مقاطعة [085] # رفع
# - * حظر (على تجارة) [085] # رفع
# - * نحو اجتماع {مطلب اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (باتجاه اجتماع) {شرط اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو اجتماع {شرط اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (باتجاه اجتماع) {مطلب اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &WEAPON   [154]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * عائق [080] # انتقل,تقدم,مشى,قام+ب,نقل
# - * منع [080] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (إلى افتراض) [192] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &MILITARY (إلى +)   [192]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * (إلى وضع) [192] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو محادثة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو مفاوضة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو مناقشة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (نحو تسريح) [0873] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (نحو تسريح) [0873] # انتقل,تقدم,مشى,قام+ب,نقل
# - * تأكيد علاقة حميم [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * دعم علاقة (مع) [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * دعم علاقة (مع ) [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - *تاكيدعلاقة وثيقة [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * قوة (نحو انسحاب) [0874] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &REFUGEE (إلى أمان)   [073]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * &REFUGEE (إلى أمان)   [073]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * حظر (على تجارة) [085] # رفع
# - * (ل) [040] # حضر,جاء,قدم,اتى
# - * (إلى) [040] # حضر,جاء,قدم,اتى
# - * (في سبيل) [020] # ضغط
# - * (من أجل) [020] # ضغط
# - * (لاجل لاجل) [020] # ضغط
# - * (من أجل) [020] # ضغط
# - * (لاجل لاجل) [020] # ضغط
# - * شكوي (مع محكمة) [115] # قدم
# - * منا شدة ضد حكم [124] # قدم
# - * استئناف ضد إدانة [124] # قدم
# - * استئناف ضد حكم [124] # قدم
# - * منا شدة ضد إدانة [124] # قدم
# - * استئناف ضد عقوبة [124] # قدم
# - * منا شدة ضد عقوبة [124] # قدم
# - * شكوي (مع محكمة) [115] # قدم
# - * منا شدة ضد حكم [124] # قدم
# - * استئناف ضد إدانة [124] # قدم
# - * استئناف ضد حكم [124] # قدم
# - * منا شدة ضد إدانة [124] # قدم
# - * استئناف ضد عقوبة [124] # قدم
# - * منا شدة ضد عقوبة [124] # قدم
# - * تعصب [124] # بقي_على,بقى,حوى,حفظ,صان,ابقى,حافظ_على,رقب
# - * تشدد [124] # بقي_على,بقى,حوى,حفظ,صان,ابقى,حافظ_على,رقب
# - * قوة [192] # بقي_على,بقى,حوى,حفظ,صان,ابقى,حافظ_على,رقب
# - * قوة [192] # بقي_على,بقى,حوى,حفظ,صان,ابقى,حافظ_على,رقب
# - * حظر [1241] # حمل,إحتفظ_بشئ_للإ_ستعمال,أيد,صمد_للحفظ,حفظ,صان,حافظ_على
# - * منع [1241] # حمل,إحتفظ_بشئ_للإ_ستعمال,أيد,صمد_للحفظ,حفظ,صان,حافظ_على
# - * قوة [192] # بقي_على,بقى,حوى,حفظ,صان,ابقى,حافظ_على,رقب
# - * قوة [192] # بقي_على,بقى,حوى,حفظ,صان,ابقى,حافظ_على,رقب
# - * &INVESTIGATION   [050]  # نقذ,وقى,حفظ,خزن,صان,نجى,وفر
# - * {عيد سنوي} [017] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * {ذكرى سنوي} [017] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * بداية ديمقراطي [035] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * ذكرى (ب واسطة احتجاج) [141] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * &FIGHT_CRIM   [1124]  # دعا+ب
# - * {عيد سنوي} [017] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * {ذكرى سنوي} [017] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * بداية ديمقراطي [035] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * ذكرى (ب واسطة احتجاج) [141] # وَضَعَ_عَلامَة_عَلَى,علم,اشر,رمز,حدد,وضع_علامة,ميز
# - * &FOOD (إلى)   [073]  # نقل
# - * &FOOD (إلى)   [073]  # نقل
# - * (في {حالة تأهب}) (على حد) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (في {حالة تأهب}) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * احتجاج [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * اعتراض [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للانتخاب) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للتصويت) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * حرارة [111] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * عصيان [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * {عمل شغب} [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (إلى موت) [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * محاكمة [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * نحو اجتماع {مطلب اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (باتجاه اجتماع) {شرط اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو اجتماع {شرط اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (باتجاه اجتماع) {مطلب اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &WEAPON   [154]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * عائق [080] # انتقل,تقدم,مشى,قام+ب,نقل
# - * منع [080] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (إلى افتراض) [192] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &MILITARY (إلى +)   [192]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * (إلى وضع) [192] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو محادثة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو مفاوضة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو مناقشة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (نحو تسريح) [0873] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (نحو تسريح) [0873] # انتقل,تقدم,مشى,قام+ب,نقل
# - * تأكيد علاقة حميم [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * دعم علاقة (مع) [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * دعم علاقة (مع ) [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - *تاكيدعلاقة وثيقة [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * قوة (نحو انسحاب) [0874] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &REFUGEE (إلى أمان)   [073]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * &REFUGEE (إلى أمان)   [073]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو اجتماع {مطلب اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (باتجاه اجتماع) {شرط اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو اجتماع {شرط اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (باتجاه اجتماع) {مطلب اقتصادي} [061] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (إلى افتراض) [192] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &MILITARY (إلى +)   [192]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * (إلى وضع) [192] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو محادثة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو مفاوضة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * نحو مناقشة [013] # انتقل,تقدم,مشى,قام+ب,نقل
# - * (نحو تسريح) [0873] # انتقل,تقدم,مشى,قام+ب,نقل
# - * تأكيد علاقة حميم [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * دعم علاقة (مع) [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * دعم علاقة (مع ) [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - *تاكيدعلاقة وثيقة [050] # انتقل,تقدم,مشى,قام+ب,نقل
# - * قوة (نحو انسحاب) [0874] # انتقل,تقدم,مشى,قام+ب,نقل
# - * &REFUGEE (إلى أمان)   [073]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * &REFUGEE (إلى أمان)   [073]  # انتقل,تقدم,مشى,قام+ب,نقل
# - * (ك &NEGOTIATOR) -   [045]  # عمل
# - * &SUSPECT   [1124]  # دعا+ب,سمى
# - * لجنة [090] # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - * (ل قيادة) [060] # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - * (كوزير) [060] # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - * (لتراس) [060] # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - * &NEGOTIATOR   [039]  # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - * سفير [050] # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - * مبعوث [050] # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - *بعثة [050] # وظف,كلفه_بأمر,عين,حكم,انتدب,وجب,نصب
# - * (ليراس) [051] # انتخب,خار,نخب
# - * ليتراس [051] # انتخب,خار,نخب
# - * (في {حالة تأهب}) (على حد) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (في {حالة تأهب}) [152] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * احتجاج [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * اعتراض [140] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للانتخاب) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (للتصويت) [014] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * حرارة [111] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * عصيان [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * {عمل شغب} [175] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * (إلى موت) [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * محاكمة [173] # وضعه_فى_موضع_معين,وضع+في,كبت,وضع,وقع,وضع+ل,نظم
# - * &FOOD (إلى)   [073]  # نقل
# - * &FOOD (إلى)   [073]  # نقل
# - * اعتناق [051] # لقى,لقي,سلم,حصل_على,تلقى,قبل,وجد,رحب,نال
# - * توكيل [051] # لقى,لقي,سلم,حصل_على,تلقى,قبل,وجد,رحب,نال
# - * تفويض [051] # لقى,لقي,سلم,حصل_على,تلقى,قبل,وجد,رحب,نال
# - * قبول [051] # لقى,لقي,سلم,حصل_على,تلقى,قبل,وجد,رحب,نال
# - * (في إقليم) [192] # توغل
# - * عمق [192] # توغل
# - * (في منطقة) [192] # توغل
# - * عميق [192] # توغل
# - * (في أرض) [192] # توغل
# - * عميق [192] # توغل
# - * (في إقليم) [192] # توغل
# - * عمق [192] # توغل
# - * (في أرض) [192] # توغل
# - * عميق [192] # توغل
# - * انتهاك [182] # التزم,تعهد
# - * (ل تعاون) [030] # التزم,تعهد
# - * منا شدة (ل اجتماع) [120] # لقى,اسقط,سقط,القى
# - * منا شدة (لاجل لاجل تجمع) [120] # لقى,اسقط,سقط,القى
# - * اتصال (ل اجتماع) [120] # لقى,اسقط,سقط,القى
# - * اتصال (لاجل لاجل اجتماع) [120] # لقى,اسقط,سقط,القى
# - * &WEAPON (على {مدى تدريب})   [150]  # لقى,اسقط,سقط,القى
# - * اتهام [081] # لقى,اسقط,سقط,القى
# - * منشورات [130] # لقى,اسقط,سقط,القى
# - * اعلانات [130] # لقى,اسقط,سقط,القى
# - * &INVESTIGATION   [080]  # لقى,اسقط,سقط,القى
# - * (في شارع) [141] # سال
# - * (إلى شارع) [141] # سال
# - * (في شارع) [141] # سال
# - * (إلى شارع) [141] # سال
# - * (حول &DISPUTE)   [010]  # شعل
# - * (عن &DISPUTE)   [010]  # شعل
# - * &DISPUTE   [110]  # شعل
# - * تأخير (محاكمة) [0351] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * تأخير محاكمة [0351] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * مخاطر [012] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * رهان [012] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * رجاء [013] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * أمل [013] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * تحذير [080] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * &CURRENCY تحت رعايات   [071]  # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * &CURRENCY تحت رعاية   [071]  # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * تأخير (محاكمة) [0351] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * تأخير محاكمة [0351] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * مخاطر [012] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * رهان [012] # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * &CURRENCY تحت رعاية   [071]  # نهض,اثار,رفع,رفع_لأعلى,جمع_تبرُّعات
# - * جمود [164] # وصل,توصُّل_إِلى,وصل+الى,وَصَلَ_إِلَى
# ...
# - *ازعاج [175] # كبت
# - *اضطراب [175] # كبت
# - * منطقة [192] # استولى+على
# - * منشا [192] # استولى+على
# - * {مقر رئيسي} [192] # استولى+على
# - * مجال [192] # استولى+على
# - * قاعدة [192] # استولى+على
# - * مساحة [192] # استولى+على
# - * {بنى تحتية} [192] # استولى+على
# - * {مسقط رأس} [192] # استولى+على
# - * {مقر قيادة} [192] # استولى+على
# - * موطن [192] # استولى+على
# NEED MANUAL FIX :- *(في مداهمة   [1711]
# -------SPECAIL----------
# old_ :- *(في مداهمة   [1711]
# new_ :SPECIAL
# -----------------
# - *بضاعة [1711] # استولى+على,استوحذ+على
# - *سلعة [1711] # استولى+على,استوحذ+على
# - *ممتلكات [1711] # استولى+على,استوحذ+على
# - * مهندس [181] # استولى+على,استوحذ+على
# - * قنصل [173] # استولى+على,استوحذ+على
# - * مطار [192] # استولى+على,استوحذ+على
# - * {ميناء جوي} [192] # استولى+على,استوحذ+على
# - * {مهبط طائرة} [192] # استولى+على,استوحذ+على
# - * سيطرة قرية [192] # استولى+على,استوحذ+على
# - * {مهبط طائرة} [192] # استولى+على,استوحذ+على
# - * تحكم قرية [192] # استولى+على,استوحذ+على
# - * رضيع [181] # خطف,اختطف
# - * طفل [181] # خطف,اختطف
# - * {أثناء المظاهرات} [175] # اعتقل
# - *أثناء المظاهرات [175] # اعتقل
# - * مساعد [173] # اعتقل
# - * ناشط [173] # اعتقل
# - * (على شك) [173] # اعتقل
# - *(في فضيحة) [173] # اعتقل
# - * (في معركة نارية) [173] # اعتقل
# - * (إلى شارع) [141] # تلقى,اخذ,سيطر+على
# - *( إلى &DETENTION)   [173]  # تلقى,اخذ,سيطر+على
# - * (بمرارة) [110] # تلقى,اخذ,سيطر+على
# - * &WEAPON   [0356]  # تلقى,اخذ,سيطر+على
# - * سيطرة [192] # تلقى,اخذ,سيطر+على
# - * مقاطعة [192] # تلقى,اخذ,سيطر+على
# - * (على &TOWN)   [192]  # تلقى,اخذ,سيطر+على
# - * مطوق [192] # تلقى,اخذ,سيطر+على
# - * تحكم [192] # تلقى,اخذ,سيطر+على
# - * محاصرة [192] # تلقى,اخذ,سيطر+على
# - * خارج تدريب &MILITARY   [1212]  # دفع_بالقوة,انسحب+من,سحب,شد,انسحب,جذب,نزع,خرج
# - * خارج ال استعمال &MILITARY   [1212]  # دفع_بالقوة,انسحب+من,سحب,شد,انسحب,جذب,نزع,خرج
# - *(من الاتلاف) [160] # دفع_بالقوة,انسحب+من,سحب,شد,انسحب,جذب,نزع,خرج
# - * (من المنافسة) [160] # دفع_بالقوة,انسحب+من,سحب,شد,انسحب,جذب,نزع,خرج
# - * (من حكومة) [161] # دفع_بالقوة,انسحب+من,سحب,شد,انسحب,جذب,نزع,خرج
# - * سفارة [161] # دفع_بالقوة,انسحب+من,سحب,شد,انسحب,جذب,نزع,خرج
# - * رجعا [0874] # دفع_بالقوة,انسحب+من,سحب,شد,انسحب,جذب,نزع,خرج
# - * (إلى شارع) [141] # تلقى,اخذ,سيطر+على
# - *( إلى &DETENTION)   [173]  # تلقى,اخذ,سيطر+على
# - * (بمرارة) [110] # تلقى,اخذ,سيطر+على
# - * &WEAPON   [0356]  # تلقى,اخذ,سيطر+على
# - * سيطرة [192] # تلقى,اخذ,سيطر+على
# - * مقاطعة [192] # تلقى,اخذ,سيطر+على
# - * (على &TOWN)   [192]  # تلقى,اخذ,سيطر+على
# - * مطوق [192] # تلقى,اخذ,سيطر+على
# - * تحكم [192] # تلقى,اخذ,سيطر+على
# - * محاصرة [192] # تلقى,اخذ,سيطر+على
# - * &SOLUTION   [129]  # اعترض+على
# - * (في محكمة) [173] # رفع+دعوى
# - * (لاجل لاجل) [173] # رفع+دعوى
# - * (في محكمة) [173] # رفع+دعوى
# - * (لاجل لاجل) [173] # رفع+دعوى
# - * (ل أجل تعاون) [166] # خلى,فصل,طرد,هجر,رحل,خرج
# - *دبلوماسي [174] # خلى,فصل,طرد,هجر,رحل,خرج
# - * (من برلمان) [1722] # خلى,فصل,طرد,هجر,رحل,خرج
# - * مقاتل [0873] # ابعد,طرد,ازل,ازال,نزع,ازح,خرج
# - * &MILITARY   [174]  # ابعد,طرد,ازل,ازال,نزع,ازح,خرج
# - * (من منصب) [160] # ابعد,طرد,ازل,ازال,نزع,ازح,خرج
# - * (من حراسة) [160] # ابعد,طرد,ازل,ازال,نزع,ازح,خرج
# - * (من مكتب) [160] # ابعد,طرد,ازل,ازال,نزع,ازح,خرج
# - * مواطن [181] # اختطف
# - * (تحت {تهديد سلاح}) [181] # اختطف
# - * قافلة [190] # تكمن+ل,كمن+ل
# - * رتل [190] # تكمن+ل,كمن+ل
# - * موكب [190] # تكمن+ل,كمن+ل
# - * &CAR   [190]  # تكمن+ل,كمن+ل
# - *بيت [1712] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - *بناية [1712] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * &WEAPON   [1712]  # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * &CAR   [1712]  # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - *بنيان [1712] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - *منزل [1712] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * معبر [190] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * {صلب &MILITARY}   [190]  # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * معسكر [190] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * جسر [190] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * مخيم [190] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * {صميم &MILITARY}   [190]  # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * {لب &MILITARY}   [190]  # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - *بيت [1712] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - *بناية [1712] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - *منزل [1712] # هدم,دمر,تلف,ألحق_الضرر_ب,خرب,ابد
# - * جمود سياسي [030] # كسر,انفصل
# - *تازم [030] # كسر,انفصل
# - * (مع) [130] # كسر,انفصل
# - * (عن) [130] # كسر,انفصل
# - * ب عيد [130] # كسر,انفصل
# - * بعيد [130] # كسر,انفصل
# - * قدميه (على) [110] # مسح
# - * تحدي [121] # قهر,اسقط,تغلّب_على,غلب,هزم
# - * &PROPOSAL   [121]  # قهر,اسقط,تغلّب_على,غلب,هزم
# - * منزل [080] # حاصر,حصر
# - * بيت [080] # حاصر,حصر
# - * (في تجارة) [061] # اجرى,قام,شارك,عمل,شغل,شبك
# - * جاهدا [060] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في مجهود) [060] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في اشتباك) [193] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في {تبادل ل إطلاق النار}) [193] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في {&FIGHT كلامي})   [111]  # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في &FIGHT_OF_WORDS)   [111]  # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في &NEGOTIATION)   [046]  # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في دبلوماسية) [030] # اجرى,قام,شارك,عمل,شغل,شبك
# - *(في دبلوماسي) [050] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في دبلوماسية) [050] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في سحب) [0874] # اجرى,قام,شارك,عمل,شغل,شبك
# - * جاهدا [060] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في {تبادل ل إطلاق النار}) [193] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في {&FIGHT كلامي})   [111]  # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في دبلوماسية) [030] # اجرى,قام,شارك,عمل,شغل,شبك
# - *(في دبلوماسي) [050] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (في دبلوماسية) [050] # اجرى,قام,شارك,عمل,شغل,شبك
# - * (ب واسطة &AIRCRAFT)   [195]  # قصف
# - * (مع حجارة) [182] # قصف
# - * (في هجمة) [194] # قصف
# - * (في غارة) [194] # قصف
# - * &WEAPON (في تدريب)   [150]  # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * (على {قاذفات قنابل}) [194] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * (على {طائرة مقاتل}) [194] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * {حاجز ناري} [194] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * {سد ناري} [194] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * &WEAPON (إلى +)   [194]  # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * (على) [190] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * ضد [190] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * (على موكب) [190] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * نحو [190] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * (على رتل) [190] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * (على قافلة) [190] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * عيارات [193] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * طلقات [193] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * رصاصات [193] # اطلق,طلق,اجج,فصل,شعل,أطْلق_سراح,زاد_النار_إشتعالا,طرد,اطلق+النار+على,اطلق+النار
# - * (ب حجارة) [182] # جرى_بسرعة,قذف,رشق,إنطلق_بسرعة_وعزم
# - * سيارة [182] # جرى_بسرعة,قذف,رشق,إنطلق_بسرعة_وعزم
# - * (ب حجارة) [145] # جرى_بسرعة,قذف,رشق,إنطلق_بسرعة_وعزم
# - * شرطة [145] # جرى_بسرعة,قذف,رشق,إنطلق_بسرعة_وعزم
# - * (ب حجر) [145] # جرى_بسرعة,قذف,رشق,إنطلق_بسرعة_وعزم
# - * (في غضب) [111] # انفجر
# - * (للمحاؤلة) [111] # هجن
# - * (لانكار) [111] # هجن
# - * (للوم) [111] # هجن
# - * &PROGRAM   [111]  # هجن
# - * (من أجل) [111] # هجن
# - * &SOLUTION   [111]  # هجن
# - * فشل [111] # هجن
# - * (ل استضافة) [111] # هجن
# - * (ل رفض) [111] # هجن
# - * (ل فرض) [111] # هجن
# - * (ل) [111] # هجن
# - * (كهزلي) [111] # هجن
# - * طريقة [111] # هجن
# - * &INFORMATION   [111]  # هجن
# - * &INVESTIGATION   [111]  # هجن
# - * (أثناء {غارة جوي}) [195] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * (خلال {غارة جوي}) [195] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * أثناء اعتقال [175] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * متظهر [175] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * (بعد &CEASEFIRE)   [196]  # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * (في {معركة بالمسدسات}) [193] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * (في اشتباك) [193] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# NEED MANUAL FIX :- * ({(في {تبادل (ل إطلاق النار)   [193]
# -------SPECAIL----------
# old_ :- * ({(في {تبادل (ل إطلاق النار)   [193]
# new_ :SPECIAL
# -----------------
# - * (بطلقات نارية) [193] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * رصاص [193] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * {إطلاق نار} [193] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * هجمة [193] # طلق,سدد,أطلق_النار_في_الهواء,أطلق_النار,أطلق_نحو_الهدف
# - * هجوم [193] # طلق,سدد,أطلق_النار_في_الهواء,أطلق_النار,أطلق_نحو_الهدف
# - * (أثناء {غارة جوي}) [195] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * (خلال {غارة جوي}) [195] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * أثناء اعتقال [175] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * متظهر [175] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * (في {معركة بالمسدسات}) [193] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# NEED MANUAL FIX :- * ({(في {تبادل (ل إطلاق النار)   [193]
# -------SPECAIL----------
# old_ :- * ({(في {تبادل (ل إطلاق النار)   [193]
# new_ :SPECIAL
# -----------------
# - * {إطلاق نار} [193] # قتل,ذبح,مات_في_ساحة_المعركة,قضى_على,امت,فتك
# - * قدميه (على) [110] # مسح
# - * (من جو) [195] # قصف
# - * (على خطة) [014] # تعمل
# - * (على سياسة) [014] # تعمل
# - * متظاهر [180] # كافح,جاهد
# - * (لاجل لاجل سيطرة) [190] # كافح,جاهد
# - * (لاجل لاجل تحكم) [190] # كافح,جاهد
# - * (لاجل لاجل تنظيم) [190] # كافح,جاهد
# - * (من أجل سيطرة) [190] # كافح,جاهد
# - * (لاجل لاجل إدارة) [190] # كافح,جاهد
# - * نقد [110] # كافح,جاهد
# - * انتقاد [110] # كافح,جاهد
# - * (في مؤتمر) [012] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (في قمة) [012] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (في قمة) [012] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * حول حبس [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (مع موظفين) [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * على احتجاز [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * على اعتقال [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (على محاولة) [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * على حبس [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * حول اعتقال [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (مع مسؤول) [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * حول احتجاز [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (على جهد) [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (حول محاولة) [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * على سجن [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (حول جهد) [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * حول سجن [110] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (حول خطة) [127] # صطدم,ضرب,صدم,تصادم,عرض,شبك,إصطدم_في_سيارة,اشتبك
# - * (ب واسطة/ب &WEAPON)   [194]  # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * (ب واسطة صاروخ) [194] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * (بصواريخ) [194] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * طائفة [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * مجموعة [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * منزل [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * {فئة منشق} [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * قاعدة [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * بيت [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * فرقة [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * هدف [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * فصيلة [190] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * حافلة [180] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * اوتوبيس [180] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * باص [180] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * الناقدين [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * طلب [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * مبعوث [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * هجوم [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * محكمة [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * حكومة [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * (في انتخاب) [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * مؤتمر [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * &PROPOSAL   [111]  # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * &TREATY   [111]  # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * (ل فشل) [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * ضد خطة [111] # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * &SUSPECT   [112]  # شنّ_هُجُوماً,عدى,أغار_على,شن_هجوما,هاجم_بعنف,هجم,هجن,هاجم,هجم+على,أَغَارَ_عَلَى,اغر
# - * مع [062] # قاوم,قتل,كفح,برز,نضل,قوم,عرك,صرع,ضاد,خَاضَ_مَعْرَكَة,صارع,خاض_معركة,قاتل,إصتدم_ب
# - * جانب (إلى) [062] # قاوم,قتل,كفح,برز,نضل,قوم,عرك,صرع,ضاد,خَاضَ_مَعْرَكَة,صارع,خاض_معركة,قاتل,إصتدم_ب
# - *(بمحاذاة) [062] # قاوم,قتل,كفح,برز,نضل,قوم,عرك,صرع,ضاد,خَاضَ_مَعْرَكَة,صارع,خاض_معركة,قاتل,إصتدم_ب
# - * منع [110] # قاوم,قتل,كفح,برز,نضل,قوم,عرك,صرع,ضاد,خَاضَ_مَعْرَكَة,صارع,خاض_معركة,قاتل,إصتدم_ب
# - * حظر [110] # قاوم,قتل,كفح,برز,نضل,قوم,عرك,صرع,ضاد,خَاضَ_مَعْرَكَة,صارع,خاض_معركة,قاتل,إصتدم_ب
# - * (ل أجل استقلال ذاوتي) [1044] # قاوم,قتل,كفح,برز,نضل,قوم,عرك,صرع,ضاد,خَاضَ_مَعْرَكَة,صارع,خاض_معركة,قاتل,إصتدم_ب
# - * (بطرق بطرق) [014] # تعمل
# - * (مع تحذير) [037] # تعمل
# - * صفقة [057] # ضرب,وقع,توصل+الى,أضرب+عن
# - * اتفاق [057] # ضرب,وقع,توصل+الى,أضرب+عن
# - * (في {ضربة جوي}) [195] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (في {هجمة جوي}) [195] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (من) [111] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (على) [111] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (ب واسطة برمانة) [193] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (بهاون) [193] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (ب رصاصة) [193] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (ب واسطة بقنبلة) [193] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (ب واسطة بهاون) [193] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (ب واسطة بقنبلة يدوي) [193] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (بطلقة) [193] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * (بعقوبات) [163] # رطم,اصيب,هجم,ضرب,رد+ضرب,تعرض
# - * بيت [175] # داهم
# - *منزل [175] # داهم
# - * بيت [175] # داهم
# - *منزل [175] # داهم
# - * هجمة [193] # طلق,سدد,أطلق_النار_في_الهواء,أطلق_النار,أطلق_نحو_الهدف
# - * هجوم [193] # طلق,سدد,أطلق_النار_في_الهواء,أطلق_النار,أطلق_نحو_الهدف
# - * (لل &WEAPON)   [194]  # وجه,استهدف,هدف
# - * (في هجمة) [190] # وجه,استهدف,هدف
# - * (في ضربة) [190] # وجه,استهدف,هدف
# - * (في هجوم) [190] # وجه,استهدف,هدف
# - * سفارة [145] # احتل
# - * معبر [192] # احتل
# - * قنصلية [192] # احتل
# - * جسر [192] # احتل
# - * قاعدة [192] # جاوز
# - *مدان [173] # عاد+اسر
# - *محكوم [173] # عاد+اسر
# - * متهم [173] # عاد+اسر
# - * (إلى قلب) [012] # صدم
# - * (إلى الصميم) [012] # صدم

# %%
with open('CAMERO.ar.txt' , 'w') as output_file:
    for line in rules: 
        output_file.write('{}\n'.format(line))
# Out:
# 6209

# %%
def udpipe(string) :
    # Prepping String 
    words  = re.findall(u'[\u0600-\u06FF]+', string) #getting arabic characters 
    data = ' '.join(words)
    
    pipe_base_url = 'http://lindat.mff.cuni.cz/services/udpipe/api/process?tokenizer&tagger' 
    attributes = {} 
    attributes['model'] = 'arabic-ud-2.0-170801'
    attributes['data'] = data

    data = requests.get(pipe_base_url , attributes)
    result = data.json()['result'].split('\n')
    udpipe_results = [re.findall(u'[\u0600-\u06FF]+', i) for i in result] # cleaning 
    udpipe_results = [i for i in udpipe_results if i !=[]]
    
    return udpipe_results

def udpipe_reconstruct(original_text) : 
    udpipe_results = udpipe(original_text)
    for i in range(1, len(udpipe_results)):
        if len(udpipe_results[i]) == 1 : # composite verbs get the next two words
            original_text =original_text.replace(udpipe_results[i][0] , '{} {}'.format(udpipe_results[i+1][1],udpipe_results[i+2][1]))
        else :
            original_text =original_text.replace(udpipe_results[i][0] , udpipe_results[i][1])
    original_text = araby.strip_tashkeel(original_text)
    return original_text


def master_reconstruct_input(text_input , input_type): 
    # type 0: none-rule just do just do udpipe_reconstruction
    # type 1 : fix the rule + do udpipe_reconstruction
    if input_type == 0:
        return udpipe_reconstruct(text_input)
    else : 
        return udpipe_reconstruct(rule(text_input))

# %%
# Out:
# 5552
